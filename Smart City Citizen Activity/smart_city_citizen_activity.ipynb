# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('smart_city_citizen_activity.csv')

# %%
data.head()
# Out:
#    Citizen_ID  Age  Gender Mode_of_Transport  Work_Hours  Shopping_Hours  \
# 0        1001   56  Female           Walking           5               2
# 1        1002   69    Male           Bicycle           0               2
# 2        1003   46    Male              Bike           0               4
# 3        1004   32    Male               Car           7               2
# 4        1005   60    Male           Walking           3               3
#
#    Entertainment_Hours  Home_Energy_Consumption_kWh  Charging_Station_Usage  \
# 0                    0                         5.32                       0
# 1                    2                         2.19                       0
# 2                    0                         4.68                       0
# 3                    3                         3.42                       0
# 4                    1                         2.79                       0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Citizen_ID                   1000 non-null   int64
#  1   Age                          1000 non-null   int64
#  2   Gender                       1000 non-null   object
#  3   Mode_of_Transport            1000 non-null   object
#  4   Work_Hours                   1000 non-null   int64
#  5   Shopping_Hours               1000 non-null   int64
#  6   Entertainment_Hours          1000 non-null   int64
#  7   Home_Energy_Consumption_kWh  1000 non-null   float64
#  8   Charging_Station_Usage       1000 non-null   int64
#  9   Carbon_Footprint_kgCO2       1000 non-null   float64
#  10  Steps_Walked                 1000 non-null   int64
#  11  Calories_Burned              1000 non-null   int64
#  12  Sleep_Hours                  1000 non-null   float64
# ...

# %%
data.shape
# Out:
# (1000, 15)

# %%
data.isnull().sum()
# Out:
# Citizen_ID                     0
# Age                            0
# Gender                         0
# Mode_of_Transport              0
# Work_Hours                     0
# Shopping_Hours                 0
# Entertainment_Hours            0
# Home_Energy_Consumption_kWh    0
# Charging_Station_Usage         0
# Carbon_Footprint_kgCO2         0
# Steps_Walked                   0
# Calories_Burned                0
# Sleep_Hours                    0
# Social_Media_Hours             0
# Public_Events_Hours            0
# dtype: int64

# %%
data.describe()
# Out:
#         Citizen_ID         Age   Work_Hours  Shopping_Hours  \
# count  1000.000000  1000.00000  1000.000000     1000.000000
# mean   1500.500000    43.81900     4.397000        2.024000
# std     288.819436    14.99103     2.870127        1.421071
# min    1001.000000    18.00000     0.000000        0.000000
# 25%    1250.750000    31.00000     2.000000        1.000000
# 50%    1500.500000    44.00000     4.000000        2.000000
# 75%    1750.250000    56.00000     7.000000        3.000000
# max    2000.000000    69.00000     9.000000        4.000000
#
#        Entertainment_Hours  Home_Energy_Consumption_kWh  \
# count          1000.000000                  1000.000000
# mean              1.532000                     5.996900
# std               1.102811                     2.302009
# min               0.000000                     2.000000
# 25%               1.000000                     4.050000
# 50%               2.000000                     5.870000
# ...

# %%
data = data.drop(columns=["Citizen_ID"])

# %%
data.head()
# Out:
#    Age  Gender Mode_of_Transport  Work_Hours  Shopping_Hours  \
# 0   56  Female           Walking           5               2
# 1   69    Male           Bicycle           0               2
# 2   46    Male              Bike           0               4
# 3   32    Male               Car           7               2
# 4   60    Male           Walking           3               3
#
#    Entertainment_Hours  Home_Energy_Consumption_kWh  Charging_Station_Usage  \
# 0                    0                         5.32                       0
# 1                    2                         2.19                       0
# 2                    0                         4.68                       0
# 3                    3                         3.42                       0
# 4                    1                         2.79                       0
#
#    Carbon_Footprint_kgCO2  Steps_Walked  Calories_Burned  Sleep_Hours  \
# ...

# %%
plt.figure(figsize=(10, 6))
plt.hist(data["Age"],color="lightblue", edgecolor="black", alpha=0.7)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age Distribution of Citizens")
plt.grid(axis="y", alpha=0.5)

plt.show()

# %%
gender_counts = data["Gender"].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(gender_counts, labels=gender_counts.index, autopct="%1.1f%%", startangle=140, colors=["lightblue", "lightcoral","gray"])
plt.title("Gender Distribution of Citizens")

plt.show()

# %%
transport_counts = data["Mode_of_Transport"].value_counts()

plt.figure(figsize=(10, 6))
plt.bar(transport_counts.index, transport_counts.values, color="lightblue", edgecolor="black")
plt.xlabel("Mode of Transport")
plt.ylabel("Frequency")
plt.title("Distribution of Transportation Modes")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--",)

plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x="Steps_Walked", y="Calories_Burned", data=data, alpha=0.6)
plt.title("Steps Walked vs Calories Burned")
plt.xlabel("Steps Walked")
plt.ylabel("Calories Burned")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()
data['Gender']=LE.fit_transform(data['Gender'])
data["Mode_of_Transport"] = LE.fit_transform(data["Mode_of_Transport"])
data.head()
# Out:
#    Age  Gender  Mode_of_Transport  Work_Hours  Shopping_Hours  \
# 0   56       0                  5           5               2
# 1   69       1                  0           0               2
# 2   46       1                  1           0               4
# 3   32       1                  2           7               2
# 4   60       1                  5           3               3
#
#    Entertainment_Hours  Home_Energy_Consumption_kWh  Charging_Station_Usage  \
# 0                    0                         5.32                       0
# 1                    2                         2.19                       0
# 2                    0                         4.68                       0
# 3                    3                         3.42                       0
# 4                    1                         2.79                       0
#
#    Carbon_Footprint_kgCO2  Steps_Walked  Calories_Burned  Sleep_Hours  \
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Mode_of_Transport', 'Work_Hours', 'Shopping_Hours',
#        'Entertainment_Hours', 'Home_Energy_Consumption_kWh',
#        'Charging_Station_Usage', 'Carbon_Footprint_kgCO2', 'Steps_Walked',
#        'Calories_Burned', 'Sleep_Hours', 'Social_Media_Hours',
#        'Public_Events_Hours'],
#       dtype='object')

# %%
# EDA
sns.histplot(data['Work_Hours'], bins=30)
plt.show()

# correlation
sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
data['Total_Activity_Hours'] = (data['Work_Hours'] + data['Shopping_Hours'] +
                              data['Entertainment_Hours'] + data['Sleep_Hours'] +
                              data['Social_Media_Hours'] + data['Public_Events_Hours'])
sns.histplot(data['Total_Activity_Hours'], bins=30)
plt.show()

# %%
sns.boxplot(x=data['Mode_of_Transport'], y=data['Work_Hours'])
plt.show()

# %%
data['activity_label'] = np.where(data['Steps_Walked'] > 5000, 'Active', 'Inactive')

# %%
data['activity_label'] = np.where(data['Carbon_Footprint_kgCO2'] > data['Carbon_Footprint_kgCO2'].median(), 'High Impact', 'Low Impact')

# %%
y=data['Carbon_Footprint_kgCO2']

features=['Age', 'Gender', 'Mode_of_Transport', 'Work_Hours', 'Shopping_Hours',
       'Entertainment_Hours', 'Home_Energy_Consumption_kWh',
       'Charging_Station_Usage', 'Steps_Walked',
       'Calories_Burned', 'Sleep_Hours', 'Social_Media_Hours',
       'Public_Events_Hours']
x=data[features]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
pip install tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.Sequential([
    layers.Input(shape=(13,)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1),
])

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
)

# %%
data.head()
# Out:
#    Age  Gender  Mode_of_Transport  Work_Hours  Shopping_Hours  \
# 0   56       0                  5           5               2
# 1   69       1                  0           0               2
# 2   46       1                  1           0               4
# 3   32       1                  2           7               2
# 4   60       1                  5           3               3
#
#    Entertainment_Hours  Home_Energy_Consumption_kWh  Charging_Station_Usage  \
# 0                    0                         5.32                       0
# 1                    2                         2.19                       0
# 2                    0                         4.68                       0
# 3                    3                         3.42                       0
# 4                    1                         2.79                       0
#
#    Carbon_Footprint_kgCO2  Steps_Walked  Calories_Burned  Sleep_Hours  \
# ...

# %%
model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 7905.8584 - val_loss: 1164.3445
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1022.8004 - val_loss: 1401.3793
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1349.1514 - val_loss: 2196.2688
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1523.9115 - val_loss: 1032.6611
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1031.9811 - val_loss: 1025.0924
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 903.0179 - val_loss: 1009.7240
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1007.2524 - val_loss: 1654.2692
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1211.9563 - val_loss: 1033.1519
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1071.9519 - val_loss: 1003.9875
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1013.6474 - val_loss: 919.8258
# Epoch 11/100
# ...

# %%
loss=model.evaluate(x_test,y_test)
print(loss)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 771.2518
# 792.6609497070312

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Mode_of_Transport', 'Work_Hours', 'Shopping_Hours',
#        'Entertainment_Hours', 'Home_Energy_Consumption_kWh',
#        'Charging_Station_Usage', 'Carbon_Footprint_kgCO2', 'Steps_Walked',
#        'Calories_Burned', 'Sleep_Hours', 'Social_Media_Hours',
#        'Public_Events_Hours', 'Total_Activity_Hours', 'activity_label'],
#       dtype='object')

# %%
new_data = pd.DataFrame({
    'Age': [32],
    'Gender': [1],
    'Mode_of_Transport': [7],
    'Work_Hours': [7],
    'Shopping_Hours': [2],
    'Entertainment_Hours': [3],
    'Home_Energy_Consumption_kWh': [3.42],
    'Charging_Station_Usage': [0],
    'Steps_Walked': [55.46],
    'Calories_Burned': [537],
    'Sleep_Hours': [4.9],
    'Social_Media_Hours': [3.5],
    'Public_Events_Hours': [0.5]
})

# %%
print(new_data.shape)
# Out:
# (1, 14)

# %%
new_data = np.array(new_data)
new_data = new_data[:, :13]

# %%
predictions = model.predict(new_data)
print(f"Predicted Carbon Footprint: {predictions[0][0]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Predicted Carbon Footprint: 8.84411907196045
